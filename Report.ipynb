# %%
import pandas as pd
from googleapiclient.discovery import build
from google.oauth2 import service_account

# %%
import numpy as np
import datetime
import pandasql

# %% [markdown]
# ## I. Download Tables from Google SpreadSheet

# %%
SERVICE_ACCOUNT_FILE = 'key.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets']
creds = None
creds = service_account.Credentials.from_service_account_file(
        SERVICE_ACCOUNT_FILE, scopes=SCOPES)

# The ID and range of a sample spreadsheet.
SAMPLE_SPREADSHEET_ID = '1Ycg7zTxds9DZnDvTrFcyNNKuTUxg6Yy6WF0a8Wc02WQ'

# %%
service = build('sheets', 'v4', credentials=creds)

# Call the Sheets API
sheet = service.spreadsheets()

# %% [markdown]
# ### Table Transactions

# %%
result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range="transactions!A1:D29001").execute()
values = result.get('values', [])

# %%
transactions = pd.DataFrame(values[1:], columns = values[0])

# %%
transactions.head()
# Out:
#                          transaction_id           created_at m_real_amount  \
# 0  2c9f1527-8e7f-4fb1-8000-c747a2ab46c9  2020-09-30 07:15:14            31
# 1  2c9f1527-8e7f-4fb1-8000-c747a2ab46c9  2020-09-30 07:15:14            87
# 2  ab8cbcf7-3271-49a0-8001-6cf9816f63b8  2020-09-12 13:47:04         49231
# 3  ab8cbcf7-3271-49a0-8001-6cf9816f63b8  2020-09-12 13:47:04         17305
# 4  52f8ebcc-d82d-4be1-8004-72cfbe0dff24  2020-09-25 06:00:07          9022
#
#                             l_client_id
# 0  8a805e60-6fd6-11e7-80fc-c412f533dba1
# 1  8a805e60-6fd6-11e7-80fc-c412f533dba1
# 2  dc0d0e52-629a-11ea-abf3-c412f533dba1
# 3  dc0d0e52-629a-11ea-abf3-c412f533dba1
# 4  e663b6a0-4a1a-11e8-a2c3-c412f533dba1

# %% [markdown]
# #### Check for the missing values

# %%
#transactions.to_csv('transactions.csv', header=True, index=False)
transactions.isna().sum()
# Out:
# transaction_id    0
# created_at        0
# m_real_amount     0
# l_client_id       0
# dtype: int64

# %% [markdown]
# #### Check types

# %%
transactions.dtypes
# Out:
# transaction_id    object
# created_at        object
# m_real_amount     object
# l_client_id       object
# dtype: object

# %% [markdown]
# #### Convert date to datetime type and amount to numeric, because we will do mathematical operations with them

# %%
transactions['created_at'] = pd.to_datetime(transactions['created_at'])

# %%
transactions['m_real_amount'] = pd.to_numeric(transactions['m_real_amount'])

# %% [markdown]
# ### Table Clients

# %%
result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range="clients!A1:C75767").execute()
values = result.get('values', [])

# %%
clients = pd.DataFrame(values[1:], columns = values[0])

# %%
clients.head()
# Out:
#                               client_id           created_at  \
# 0  0001da7d-fcda-11ea-ac18-c412f533dba1  2020-09-22 17:46:23
# 1  000a8743-9ae1-11e7-8114-c412f533dba1  2017-09-16 00:00:00
# 2  000ae57e-2d48-11ea-abeb-c412f533dba1  2020-01-02 14:08:56
# 3  00133cde-481c-11ea-abeb-c412f533dba1  2020-02-05 17:25:13
# 4  00148d3f-07e6-11e8-812a-c412f533dba1  2018-02-02 00:00:00
#
#                            l_manager_id
# 0  9a87c608-52dc-11ea-abeb-c412f533dba1
# 1  ad52c7a8-a752-11e7-8115-c412f533dba1
# 2  43756fa4-57a0-11e9-ab9a-c412f533dba1
# 3  9a87c608-52dc-11ea-abeb-c412f533dba1
# 4  abed5496-ca88-11e9-abb8-c412f533dba1

# %% [markdown]
# #### Check for the missing values

# %%
#clients.to_csv('clients.csv', header=True, index=False)
clients.isna().sum()
# Out:
# client_id        0
# created_at      42
# l_manager_id    42
# dtype: int64

# %% [markdown]
# #### Check types

# %%
clients.dtypes
# Out:
# client_id       object
# created_at      object
# l_manager_id    object
# dtype: object

# %% [markdown]
# We see, that there is date 0001-01-01 00:00:00 is used as N/A. Therefore, we can fill N/A and this value by the following date: 01/01/1900

# %%
clients['created_at'] = pd.to_datetime(clients['created_at'], errors = 'coerce')
clients['created_at'] = clients['created_at'].fillna(datetime.datetime(1900, 1, 1))

# %% [markdown]
# To fill in the missing values we have to look at the other tables with manager_id. In table LEADS, we see the use of 00000000-0000-0000-0000-000000000000 as the undefined manager_id, so we can use it as well

# %%
clients['l_manager_id'] = clients['l_manager_id'].fillna('00000000-0000-0000-0000-000000000000')

# %% [markdown]
# ## Table Managers

# %%
result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range="managers!A1:C14").execute()
values = result.get('values', [])

# %%
managers = pd.DataFrame(values[1:], columns = values[0])

# %% [markdown]
# This table is small, so we can look at the whole table

# %%
#managers.to_csv('managers.csv', header=True, index=False)
managers
# Out:
#                               manager_id    d_manager   d_club
# 0   1e9c5562-0cfc-11ea-abe1-c412f533dba1   manager #8  club #2
# 1   43756fa4-57a0-11e9-ab9a-c412f533dba1  manager #11  club #4
# 2   543888c4-fbb3-11e9-abdc-c412f533dba1  manager #12  club #3
# 3   5dd88f32-6501-11ea-abf3-c412f533dba1  manager #10  club #2
# 4   9a87c608-52dc-11ea-abeb-c412f533dba1   manager #9  club #3
# 5   abed5496-ca88-11e9-abb8-c412f533dba1   manager #5  club #4
# 6   ad52c7a8-a752-11e7-8115-c412f533dba1   manager #7  club #1
# 7   b55a233c-5df6-11ea-abf2-c412f533dba1   manager #2  club #4
# 8   b832aac3-fcda-11ea-ac18-c412f533dba1  manager #13  club #3
# 9   d12fe765-b444-11e9-abb3-c412f533dba1   manager #1  club #1
# 10  db06b8bc-bfb2-11e7-8116-c412f533dba1   manager #4  club #2
# 11  e463b03f-2d74-11eb-ac1f-c412f533dba1   manager #3  club #1
# 12  f44596c6-12cd-11eb-ac1c-c412f533dba1   manager #6  club #2

# %% [markdown]
# ### Table Leads

# %%
result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range="leads!A1:F3338").execute()
values = result.get('values', [])

# %%
leads = pd.DataFrame(values[1:], columns = values[0])

# %%
leads.head()
# Out:
#                                 lead_id           created_at d_utm_medium  \
# 0  00678e71-0fb9-11eb-ac1a-c412f533dba1  2020-10-16 18:08:09          sms
# 1  0078b05d-0f1f-11eb-ac1a-c412f533dba1  2020-10-15 23:45:40          cpc
# 2  007d1401-2af3-11eb-ac1f-c412f533dba1  2020-11-20 09:41:14          cpc
# 3  0084e614-2fcc-11eb-ac1f-c412f533dba1  2020-11-26 13:44:40
# 4  009b1616-145d-11eb-ac1d-c412f533dba1  2020-10-22 15:52:04          cpc
#
#   d_utm_source                          l_manager_id  \
# 0        viber  1e9c5562-0cfc-11ea-abe1-c412f533dba1
# 1    instagram  d12fe765-b444-11e9-abb3-c412f533dba1
# 2    instagram  43756fa4-57a0-11e9-ab9a-c412f533dba1
# 3               00000000-0000-0000-0000-000000000000
# 4           vk  5dd88f32-6501-11ea-abf3-c412f533dba1
#
#                             l_client_id
# 0  7264cf21-a31d-11e9-abb0-c412f533dba1
# 1  606c5b29-0f88-11eb-ac1a-c412f533dba1
# 2  1f389c6a-d5ab-11e9-abbe-c412f533dba1
# 3  00000000-0000-0000-0000-000000000000
# 4  ac2c0012-6fd5-11e7-80fc-c412f533dba1

# %% [markdown]
# #### Check for the missing values

# %%
#leads.to_csv('leads.csv', header=True, index=False)
leads.isna().sum()
# Out:
# lead_id         0
# created_at      0
# d_utm_medium    0
# d_utm_source    0
# l_manager_id    0
# l_client_id     0
# dtype: int64

# %% [markdown]
# #### Check types

# %%
leads.dtypes
# Out:
# lead_id         object
# created_at      object
# d_utm_medium    object
# d_utm_source    object
# l_manager_id    object
# l_client_id     object
# dtype: object

# %% [markdown]
# #### Convert date to datetime type

# %%
leads['created_at'] = pd.to_datetime(leads['created_at'])

# %% [markdown]
# ## II. Preparation of the Report

# %% [markdown]
# ### Set the time period

# %%
x = datetime.datetime(2020, 10, 17)
y = datetime.datetime(2020, 11, 17)

# %%
d = {'x': [x], 'y': [y]}
period = pd.DataFrame(data=d)
period
# Out:
#            x          y
# 0 2020-10-17 2020-11-17

# %% [markdown]
# #### Check the source column

# %%
leads['d_utm_source'].unique()
# Out:
# array(['viber', 'instagram', '', 'vk', 'sms', 'google', 'utm_source',
#        'insta', 'vkontakte', 'yandex', 'ycard',
#        'ycard#!/tproduct/225696739-1498486363994', 'ig'], dtype=object)

# %%
condition = leads['d_utm_source'].str.contains('ycard')
leads['d_utm_source'] = np.where(condition, 'ycard', leads['d_utm_source'])
condition = leads['d_utm_source'].str.contains('insta')
leads['d_utm_source'] = np.where(condition, 'instagram', leads['d_utm_source'])
condition = leads['d_utm_source'].str.contains('vk')
leads['d_utm_source'] = np.where(condition, 'vk', leads['d_utm_source'])

# %%
leads['d_utm_source'].unique()
# Out:
# array(['viber', 'instagram', '', 'vk', 'sms', 'google', 'utm_source',
#        'yandex', 'ycard', 'ig'], dtype=object)

# %%
leads['d_utm_source'].replace('', 'unknown', inplace=True)
leads['d_utm_source'].replace('utm_source', 'unknown', inplace=True)

# %%
leads.head()
# Out:
#                                 lead_id          created_at d_utm_medium  \
# 0  00678e71-0fb9-11eb-ac1a-c412f533dba1 2020-10-16 18:08:09          sms
# 1  0078b05d-0f1f-11eb-ac1a-c412f533dba1 2020-10-15 23:45:40          cpc
# 2  007d1401-2af3-11eb-ac1f-c412f533dba1 2020-11-20 09:41:14          cpc
# 3  0084e614-2fcc-11eb-ac1f-c412f533dba1 2020-11-26 13:44:40
# 4  009b1616-145d-11eb-ac1d-c412f533dba1 2020-10-22 15:52:04          cpc
#
#   d_utm_source                          l_manager_id  \
# 0        viber  1e9c5562-0cfc-11ea-abe1-c412f533dba1
# 1    instagram  d12fe765-b444-11e9-abb3-c412f533dba1
# 2    instagram  43756fa4-57a0-11e9-ab9a-c412f533dba1
# 3      unknown  00000000-0000-0000-0000-000000000000
# 4           vk  5dd88f32-6501-11ea-abf3-c412f533dba1
#
#                             l_client_id
# 0  7264cf21-a31d-11e9-abb0-c412f533dba1
# 1  606c5b29-0f88-11eb-ac1a-c412f533dba1
# 2  1f389c6a-d5ab-11e9-abbe-c412f533dba1
# 3  00000000-0000-0000-0000-000000000000
# 4  ac2c0012-6fd5-11e7-80fc-c412f533dba1

# %% [markdown]
# Check that all the clients with id in the table leads are in the table clients

# %%
sub_data1 = pandasql.sqldf("SELECT DISTINCT leads.l_client_id FROM leads LEFT JOIN clients ON leads.l_client_id = clients.client_id;", globals())
sub_data2 = pandasql.sqldf("SELECT DISTINCT leads.l_client_id FROM leads INNER JOIN clients ON leads.l_client_id = clients.client_id;", globals()) 
pd.concat([sub_data1,sub_data2]).drop_duplicates(keep=False)
# Out:
#                             l_client_id
# 3  00000000-0000-0000-0000-000000000000

# %% [markdown]
# Check that all the clients with transactions are in the table clients

# %%
sub_data1 = pandasql.sqldf("SELECT DISTINCT transactions.l_client_id FROM transactions LEFT JOIN clients ON transactions.l_client_id = clients.client_id;", globals())
sub_data2 = pandasql.sqldf("SELECT DISTINCT transactions.l_client_id FROM transactions INNER JOIN clients ON transactions.l_client_id = clients.client_id;", globals()) 
pd.concat([sub_data1,sub_data2]).drop_duplicates(keep=False)
# Out:
# Empty DataFrame
# Columns: [l_client_id]
# Index: []

# %% [markdown]
# Check that all clients without manager in leads and in transactions have managers

# %%
client_no_manager = pandasql.sqldf("SELECT l_client_id FROM leads WHERE l_manager_id = '00000000-0000-0000-0000-000000000000' AND l_client_id <> '00000000-0000-0000-0000-000000000000';", globals())

# %%
clients.loc[clients['client_id'].isin(client_no_manager['l_client_id'])]
# Out:
#                                   client_id          created_at  \
# 2381   086ee5d4-620d-11ea-abf3-c412f533dba1 2020-03-09 17:50:43
# 8678   1d9a669a-d5a5-11e9-abbe-c412f533dba1 1900-01-01 00:00:00
# 8725   1da0523f-d5b5-11e9-abbe-c412f533dba1 1900-01-01 00:00:00
# 11132  251d41aa-c96b-11e9-abb7-c412f533dba1 2019-08-28 00:00:00
# 11327  25bda8e3-d5ac-11e9-abbe-c412f533dba1 1900-01-01 00:00:00
# 13139  2b0c485e-d5a6-11e9-abbe-c412f533dba1 1900-01-01 00:00:00
# 13239  2b361f83-0fbd-11eb-ac1a-c412f533dba1 2020-10-16 18:37:52
# 15036  31b2d371-0a06-11eb-ac1a-c412f533dba1 2020-10-09 12:05:36
# 17464  394eadaf-19dc-11eb-ac1d-c412f533dba1 2020-10-29 15:45:21
# 18866  3d80f361-302e-11e8-8131-c412f533dba1 2018-03-25 00:00:00
# 18931  3dacebfa-09f9-11eb-ac1a-c412f533dba1 2020-10-09 10:32:46
# 22610  4a126120-d5a3-11e9-abbe-c412f533dba1 1900-01-01 00:00:00
# 23512  4c992d05-d5a6-11e9-abbe-c412f533dba1 1900-01-01 00:00:00
# 24204  4ea31992-11da-11eb-ac1c-c412f533dba1 2020-10-19 11:11:29
# 26095  5545c2c2-d5b4-11e9-abbe-c412f533dba1 1900-01-01 00:00:00
#
db06b8bc-bfb2-11e7-8116-c412f533dba1
# 53059  fb7cd115-9bb6-11e8-ab51-c412f533dba1
# 56619  b55a233c-5df6-11ea-abf2-c412f533dba1
# 58484  bf340611-034b-11eb-ac18-c412f533dba1
# 58716  9a87c608-52dc-11ea-abeb-c412f533dba1
# 65052  9a87c608-52dc-11ea-abeb-c412f533dba1
# 65509  fb7cd115-9bb6-11e8-ab51-c412f533dba1

# %%
client_and_manager = pandasql.sqldf("SELECT DISTINCT l_client_id, l_manager_id FROM leads;", globals())
client_and_manager
# Out:
#                                l_client_id  \
# 0     7264cf21-a31d-11e9-abb0-c412f533dba1
# 1     606c5b29-0f88-11eb-ac1a-c412f533dba1
# 2     1f389c6a-d5ab-11e9-abbe-c412f533dba1
# 3     00000000-0000-0000-0000-000000000000
# 4     ac2c0012-6fd5-11e7-80fc-c412f533dba1
# ...                                    ...
# 2291  ffa2180f-1f72-11eb-ac1d-c412f533dba1
# 2292  ffaa0816-16c4-11eb-ac1d-c412f533dba1
# 2293  377ea5e0-d089-11e9-abbd-c412f533dba1
# 2294  6dd39f15-d5a3-11e9-abbe-c412f533dba1
# 2295  f3357d13-15c7-11eb-ac1d-c412f533dba1
#
#                               l_manager_id
# 0     1e9c5562-0cfc-11ea-abe1-c412f533dba1
# 1     d12fe765-b444-11e9-abb3-c412f533dba1
# 2     43756fa4-57a0-11e9-ab9a-c412f533dba1
# 3     00000000-0000-0000-0000-000000000000
# 4     5dd88f32-6501-11ea-abf3-c412f533dba1
# ...                                    ...
# 2291  b832aac3-fcda-11ea-ac18-c412f533dba1
# 2292  5dd88f32-6501-11ea-abf3-c412f533dba1
# 2293  ad52c7a8-a752-11e7-8115-c412f533dba1
# 2294  5dd88f32-6501-11ea-abf3-c412f533dba1
# 2295  ad52c7a8-a752-11e7-8115-c412f533dba1
#
# [2296 rows x 2 columns]

# %%
pandasql.sqldf("SELECT COUNT(l_client_id) FROM client_and_manager GROUP BY l_client_id HAVING COUNT(l_client_id)>1;", globals())
# Out:
#     COUNT(l_client_id)
# 0                   17
# 1                    2
# 2                    2
# 3                    2
# 4                    3
# ..                 ...
# 83                   2
# 84                   2
# 85                   2
# 86                   2
# 87                   2
#
# [88 rows x 1 columns]

# %% [markdown]
# We see that one client can have many managers.

# %% [markdown]
# ### Create spread sheet

# %%
# Find the first lead for each client
first_lead = leads[['l_client_id','created_at']].groupby(['l_client_id']).min()
first_lead.reset_index(inplace=True)

# %%
# Add indicator column of the first lead
leads = pd.merge(leads, first_lead, on='l_client_id', how='left')
leads['First'] = leads['created_at_x']==leads['created_at_y']
leads.drop(columns=['created_at_y'],inplace=True)
leads.rename(columns={"created_at_x": "created_at"},inplace=True)

# %%
# Find the first transaction for each client
first_trans = transactions[['l_client_id','created_at']].groupby(['l_client_id']).min()
first_trans.reset_index(inplace=True)

# %%
# Add indicator column of the first transaction
transactions = pd.merge(transactions, first_trans, on='l_client_id', how='left')
transactions['First'] = transactions['created_at_x']==transactions['created_at_y']
transactions.drop(columns=['created_at_y'],inplace=True)
transactions.rename(columns={"created_at_x": "created_at"},inplace=True)

# %% [markdown]
# Let's analyse the 0000 managers. Look at first lead, manager's record and purchase:

# %%
tmp = leads[(leads['l_manager_id']=='00000000-0000-0000-0000-000000000000') & (leads['First']==True)]['l_client_id'].to_list()
#tt = pandasql.sqldf("SELECT leads.l_client_id, leads.l_id, clients.l_manager_id, leads.created_at AS first_lead, clients.created_at AS manager_record FROM transactions, leads LEFT JOIN clients ON leads.l_client_id = clients.client_id WHERE leads.l_manager_id = '00000000-0000-0000-0000-000000000000';", globals())
# 17                                   NaN                 NaT            NaN
# 36                                   NaN                 NaT            NaN
# 18  872f7dd7-e41e-4f0b-8fa6-8c4bc6b5c17c 2020-01-14 03:14:46        11345.0
# 7                                    NaN                 NaT            NaN
# 30  6840489c-cf62-4108-9abe-6b520e7947ba 2020-10-17 09:02:51         5099.0
#
#    First_y
# 24    True
# 6      NaN
# 27    True
# 35    True
# 29    True
# 37     NaN
# 2      NaN
# 22     NaN
# 8      NaN
# 16     NaN
# 31    True
# 14    True
# 15     NaN
# 21     NaN
# 32     NaN
# 13     NaN
# 19     NaN
# 26     NaN
# 20     NaN
# 4     True
# 33    True
# 38    True
# 12    True
# 34    True
# 5     True
# 0     True
# 10    True
# 25     NaN
# 3     True
# 23     NaN
# 9      NaN
# 28     NaN
# 1      NaN
# 11     NaN
# 17     NaN
# 36     NaN
# 18    True
# 7      NaN
# 30    True

# %% [markdown]
# 1. From the first line, we see that transaction could happen without lead, but there was a manager.
#
# 2. We see that some transactions were created without a manager, but then the client was included in the database by a manager.

# %%
#leads = pandasql.sqldf("SELECT leads.lead_id, leads.created_at, leads.d_utm_medium, leads.d_utm_source, CASE WHEN leads.l_manager_id = '00000000-0000-0000-0000-000000000000' AND leads.l_client_id <> '00000000-0000-0000-0000-000000000000' THEN clients.l_manager_id ELSE leads.l_manager_id END AS l_manager_id, leads.l_client_id FROM leads LEFT JOIN clients ON leads.l_client_id=clients.client_id;", globals())

# %%
#leads['created_at'] = pd.to_datetime(leads['created_at'])

# %% [markdown]
# Select the specific time period

# %%
# Select the data in the time period
result = leads[(leads['created_at']>period.x[0]) & (leads['created_at']<period.y[0])].copy()
#result = pandasql.sqldf("SELECT leads.created_at, leads.d_utm_source, CASE WHEN leads.l_manager_id = '00000000-0000-0000-0000-000000000000' THEN 'No manager' ELSE managers.d_manager END AS manager, CASE WHEN leads.l_manager_id = '00000000-0000-0000-0000-000000000000' THEN 'No club' ELSE managers.d_club END AS club, leads.l_client_id, CASE WHEN leads.l_client_id IN (SELECT DISTINCT leads.l_client_id FROM leads, period WHERE leads.created_at < period.x UNION SELECT DISTINCT transactions.l_client_id FROM transactions, period WHERE transactions.created_at < period.x) THEN 'Old' ELSE 'New' END AS New FROM period, leads LEFT JOIN managers ON leads.l_manager_id=managers.manager_id WHERE leads.created_at BETWEEN period.x AND period.y ORDER BY leads.l_client_id;", globals())

# %%
result.head()
# Out:
#                                  lead_id          created_at d_utm_medium  \
# 4   009b1616-145d-11eb-ac1d-c412f533dba1 2020-10-22 15:52:04          cpc
# 6   00aea163-13a5-11eb-ac1d-c412f533dba1 2020-10-21 17:54:59
# 7   00b288c8-1f2a-11eb-ac1d-c412f533dba1 2020-11-05 09:44:43          cpc
# 8   00c4c14a-2456-11eb-ac1d-c412f533dba1 2020-11-11 23:42:17          cpc
# 10  010e6800-1b56-11eb-ac1d-c412f533dba1 2020-10-31 12:49:37          cpc
#
#    d_utm_source                          l_manager_id  \
# 4            vk  5dd88f32-6501-11ea-abf3-c412f533dba1
# 6       unknown  db06b8bc-bfb2-11e7-8116-c412f533dba1
# 7     instagram  43756fa4-57a0-11e9-ab9a-c412f533dba1
# 8        google  5dd88f32-6501-11ea-abf3-c412f533dba1
# 10    instagram  db06b8bc-bfb2-11e7-8116-c412f533dba1
#
#                              l_client_id  First
# 4   ac2c0012-6fd5-11e7-80fc-c412f533dba1   True
# 6   00aea164-13a5-11eb-ac1d-c412f533dba1   True
# 7   9c1b0cfa-fd6b-11ea-ac18-c412f533dba1   True
# 8   bb2c46b7-24b5-11eb-ac1d-c412f533dba1   True
# 10  43836482-981e-11e9-abac-c412f533dba1   True

# %% [markdown]
# Date of the first purchase for each client:

# %%
result = pd.merge(result, transactions[transactions['First']==True], on='l_client_id', how='left')
result.drop(columns=['First_y', 'transaction_id'],inplace=True)
result['m_real_amount'] = result['m_real_amount'].fillna(0)
result['created_at_y'] = result['created_at_y'].fillna(datetime.datetime(2090, 1, 1))
result
# Out:
#                                    lead_id        created_at_x d_utm_medium  \
# 0     009b1616-145d-11eb-ac1d-c412f533dba1 2020-10-22 15:52:04          cpc
# 1     00aea163-13a5-11eb-ac1d-c412f533dba1 2020-10-21 17:54:59
# 2     00b288c8-1f2a-11eb-ac1d-c412f533dba1 2020-11-05 09:44:43          cpc
# 3     00c4c14a-2456-11eb-ac1d-c412f533dba1 2020-11-11 23:42:17          cpc
# 4     010e6800-1b56-11eb-ac1d-c412f533dba1 2020-10-31 12:49:37          cpc
# ...                                    ...                 ...          ...
# 1970  ff7d0045-12c7-11eb-ac1c-c412f533dba1 2020-10-20 15:32:56          sms
# 1971  ffa2180e-1f72-11eb-ac1d-c412f533dba1 2020-11-05 18:27:15
# 1972  ffaa0815-16c4-11eb-ac1d-c412f533dba1 2020-10-25 17:21:33
# 1973  ffacb5af-194f-11eb-ac1d-c412f533dba1 2020-10-28 23:01:35          cpc
# 1974  ffcdebc8-15c2-11eb-ac1d-c412f533dba1 2020-10-24 10:34:43   utm_medium
#
#      d_utm_source                          l_manager_id  \
# 0              vk  5dd88f32-6501-11ea-abf3-c412f533dba1
# 1         unknown  db06b8bc-bfb2-11e7-8116-c412f533dba1
# 2       instagram  43756fa4-57a0-11e9-ab9a-c412f533dba1
# 3          google  5dd88f32-6501-11ea-abf3-c412f533dba1
# 4       instagram  db06b8bc-bfb2-11e7-8116-c412f533dba1
# ...           ...                                   ...
# 1970        viber  9a87c608-52dc-11ea-abeb-c412f533dba1
# 1971      unknown  b832aac3-fcda-11ea-ac18-c412f533dba1
# 1972      unknown  5dd88f32-6501-11ea-abf3-c412f533dba1
# 1973           vk  ad52c7a8-a752-11e7-8115-c412f533dba1
# 1974      unknown  ad52c7a8-a752-11e7-8115-c412f533dba1
#
#                                l_client_id  First_x        created_at_y  \
# 0     ac2c0012-6fd5-11e7-80fc-c412f533dba1     True 2020-04-17 14:48:51
# 1     00aea164-13a5-11eb-ac1d-c412f533dba1     True 2090-01-01 00:00:00
# 2     9c1b0cfa-fd6b-11ea-ac18-c412f533dba1     True 2090-01-01 00:00:00
# 3     bb2c46b7-24b5-11eb-ac1d-c412f533dba1     True 2020-11-20 07:59:19
# 4     43836482-981e-11e9-abac-c412f533dba1     True 2020-11-27 17:17:33
# ...                                    ...      ...                 ...
# 1970  2e4fbe67-12cb-11eb-ac1c-c412f533dba1     True 2090-01-01 00:00:00
# 1971  ffa2180f-1f72-11eb-ac1d-c412f533dba1     True 2020-11-05 15:29:21
# 1972  ffaa0816-16c4-11eb-ac1d-c412f533dba1     True 2090-01-01 00:00:00
# 1973  377ea5e0-d089-11e9-abbd-c412f533dba1     True 2090-01-01 00:00:00
# 1974  f3357d13-15c7-11eb-ac1d-c412f533dba1     True 2090-01-01 00:00:00
#
#       m_real_amount
# 0           13040.0
# 1               0.0
# 2               0.0
# 3            8349.0
# 4           23641.0
# ...             ...
# 1970            0.0
# 1971          747.0
# 1972            0.0
# 1973            0.0
# 1974            0.0
#
# [1975 rows x 9 columns]

# %%
result.rename(columns={"created_at_y": "first_purch"},inplace=True)
result['no_purch_before'] = result['created_at_x'] < result['first_purch']

# %%
# Find clients with purchases
result['purchase'] = result.apply(lambda x : 'Yes' if (x['created_at_x']<transactions[transactions['l_client_id']==x['l_client_id']]['created_at']).any() and (transactions[transactions['l_client_id']==x['l_client_id']]['created_at']<x['created_at_x']+datetime.timedelta(days=7)).any() else 'No', axis=1)

# %%
result
# Out:
#                                    lead_id        created_at_x d_utm_medium  \
# 0     009b1616-145d-11eb-ac1d-c412f533dba1 2020-10-22 15:52:04          cpc
# 1     00aea163-13a5-11eb-ac1d-c412f533dba1 2020-10-21 17:54:59
# 2     00b288c8-1f2a-11eb-ac1d-c412f533dba1 2020-11-05 09:44:43          cpc
# 3     00c4c14a-2456-11eb-ac1d-c412f533dba1 2020-11-11 23:42:17          cpc
# 4     010e6800-1b56-11eb-ac1d-c412f533dba1 2020-10-31 12:49:37          cpc
# ...                                    ...                 ...          ...
# 1970  ff7d0045-12c7-11eb-ac1c-c412f533dba1 2020-10-20 15:32:56          sms
# 1971  ffa2180e-1f72-11eb-ac1d-c412f533dba1 2020-11-05 18:27:15
# 1972  ffaa0815-16c4-11eb-ac1d-c412f533dba1 2020-10-25 17:21:33
# 1973  ffacb5af-194f-11eb-ac1d-c412f533dba1 2020-10-28 23:01:35          cpc
# 1974  ffcdebc8-15c2-11eb-ac1d-c412f533dba1 2020-10-24 10:34:43   utm_medium
#
#      d_utm_source                          l_manager_id  \
# 0              vk  5dd88f32-6501-11ea-abf3-c412f533dba1
# 1         unknown  db06b8bc-bfb2-11e7-8116-c412f533dba1
# 2       instagram  43756fa4-57a0-11e9-ab9a-c412f533dba1
# 3          google  5dd88f32-6501-11ea-abf3-c412f533dba1
# 4       instagram  db06b8bc-bfb2-11e7-8116-c412f533dba1
# ...           ...                                   ...
# 1970        viber  9a87c608-52dc-11ea-abeb-c412f533dba1
# 1971      unknown  b832aac3-fcda-11ea-ac18-c412f533dba1
# 1972      unknown  5dd88f32-6501-11ea-abf3-c412f533dba1
# 1973           vk  ad52c7a8-a752-11e7-8115-c412f533dba1
# 1974      unknown  ad52c7a8-a752-11e7-8115-c412f533dba1
#
#                                l_client_id  First_x         first_purch  \
# 0     ac2c0012-6fd5-11e7-80fc-c412f533dba1     True 2020-04-17 14:48:51
# 1     00aea164-13a5-11eb-ac1d-c412f533dba1     True 2090-01-01 00:00:00
# 2     9c1b0cfa-fd6b-11ea-ac18-c412f533dba1     True 2090-01-01 00:00:00
# 3     bb2c46b7-24b5-11eb-ac1d-c412f533dba1     True 2020-11-20 07:59:19
# 4     43836482-981e-11e9-abac-c412f533dba1     True 2020-11-27 17:17:33
# ...                                    ...      ...                 ...
# 1970  2e4fbe67-12cb-11eb-ac1c-c412f533dba1     True 2090-01-01 00:00:00
# 1971  ffa2180f-1f72-11eb-ac1d-c412f533dba1     True 2020-11-05 15:29:21
# 1972  ffaa0816-16c4-11eb-ac1d-c412f533dba1     True 2090-01-01 00:00:00
# 1973  377ea5e0-d089-11e9-abbd-c412f533dba1     True 2090-01-01 00:00:00
# 1974  f3357d13-15c7-11eb-ac1d-c412f533dba1     True 2090-01-01 00:00:00
#
#       m_real_amount  no_purch_before purchase
# 0           13040.0            False       No
# 1               0.0             True       No
# 2               0.0             True       No
# 3            8349.0             True       No
# 4           23641.0             True       No
# ...             ...              ...      ...
# 1970            0.0             True       No
# 1971          747.0            False       No
# 1972            0.0             True       No
# 1973            0.0             True       No
# 1974            0.0             True       No
#
# [1975 rows x 11 columns]

# %%
result['client_status'] = result.apply(lambda x : 'Trash' if x['l_client_id'] == '00000000-0000-0000-0000-000000000000' else x['First_x'], axis=1)

# %%
result['client_status'].replace([True, False], ['Yes', 'No'], inplace=True)
#result.drop(columns=['First_x'],inplace=True)
result['client_status'] = result.apply(lambda x : 'No' if (x['client_status'] == 'Yes') and (x['no_purch_before']==False) else x['client_status'], axis=1)

# %%
result.head(20)
# Out:
#                                  lead_id        created_at_x d_utm_medium  \
# 0   009b1616-145d-11eb-ac1d-c412f533dba1 2020-10-22 15:52:04          cpc
# 1   00aea163-13a5-11eb-ac1d-c412f533dba1 2020-10-21 17:54:59
# 2   00b288c8-1f2a-11eb-ac1d-c412f533dba1 2020-11-05 09:44:43          cpc
# 3   00c4c14a-2456-11eb-ac1d-c412f533dba1 2020-11-11 23:42:17          cpc
# 4   010e6800-1b56-11eb-ac1d-c412f533dba1 2020-10-31 12:49:37          cpc
# 5   012af3e3-1faa-11eb-ac1d-c412f533dba1 2020-11-06 01:00:59          cpc
# 6   0165bb18-2743-11eb-ac1d-c412f533dba1 2020-11-15 17:03:56          cpc
# 7   016f5641-21c0-11eb-ac1d-c412f533dba1 2020-11-08 16:43:31
# 8   01769e26-19dd-11eb-ac1d-c412f533dba1 2020-10-29 15:51:05          cpc
# 9   018378bf-1796-11eb-ac1d-c412f533dba1 2020-10-26 18:17:41
# 10  018bfd62-21ef-11eb-ac1d-c412f533dba1 2020-11-08 22:19:58
# 11  01a8e838-1d1f-11eb-ac1d-c412f533dba1 2020-11-02 19:20:58          cpc
# 12  01c6d549-1f6c-11eb-ac1d-c412f533dba1 2020-11-05 17:37:12          cpc
# 13  0207bcb4-1f34-11eb-ac1d-c412f533dba1 2020-11-05 10:56:20          cpc
# 14  020a526c-258c-11eb-ac1d-c412f533dba1 2020-11-13 12:41:23   utm_medium
# 15  02310513-2344-11eb-ac1d-c412f533dba1 2020-11-10 15:00:57
# 16  0239cc93-16dd-11eb-ac1d-c412f533dba1 2020-10-25 20:13:25   utm_medium
# 17  0244e433-1952-11eb-ac1d-c412f533dba1 2020-10-28 23:16:05          cpc
# 18  02554de5-12c9-11eb-ac1c-c412f533dba1 2020-10-20 15:40:11          sms
# 19  02879318-1692-11eb-ac1d-c412f533dba1 2020-10-25 11:16:33          cpc
#
#    d_utm_source                          l_manager_id  \
# 0            vk  5dd88f32-6501-11ea-abf3-c412f533dba1
# 1       unknown  db06b8bc-bfb2-11e7-8116-c412f533dba1
# 2     instagram  43756fa4-57a0-11e9-ab9a-c412f533dba1
# 3        google  5dd88f32-6501-11ea-abf3-c412f533dba1
# 4     instagram  db06b8bc-bfb2-11e7-8116-c412f533dba1
# 5     instagram  db06b8bc-bfb2-11e7-8116-c412f533dba1
# 6     instagram  db06b8bc-bfb2-11e7-8116-c412f533dba1
# 7       unknown  b832aac3-fcda-11ea-ac18-c412f533dba1
# 8     instagram  ad52c7a8-a752-11e7-8115-c412f533dba1
# 9       unknown  43756fa4-57a0-11e9-ab9a-c412f533dba1
# 10      unknown  00000000-0000-0000-0000-000000000000
# 11    instagram  db06b8bc-bfb2-11e7-8116-c412f533dba1
# 12    instagram  b832aac3-fcda-11ea-ac18-c412f533dba1
# 13    instagram  b832aac3-fcda-11ea-ac18-c412f533dba1
# 14      unknown  43756fa4-57a0-11e9-ab9a-c412f533dba1
# 15      unknown  00000000-0000-0000-0000-000000000000
# 16      unknown  9a87c608-52dc-11ea-abeb-c412f533dba1
# 17    instagram  ad52c7a8-a752-11e7-8115-c412f533dba1
# 18        viber  1e9c5562-0cfc-11ea-abe1-c412f533dba1
# 19    instagram  d12fe765-b444-11e9-abb3-c412f533dba1
#
#                              l_client_id  First_x         first_purch  \
# 0   ac2c0012-6fd5-11e7-80fc-c412f533dba1     True 2020-04-17 14:48:51
# 1   00aea164-13a5-11eb-ac1d-c412f533dba1     True 2090-01-01 00:00:00
# 2   9c1b0cfa-fd6b-11ea-ac18-c412f533dba1     True 2090-01-01 00:00:00
# 3   bb2c46b7-24b5-11eb-ac1d-c412f533dba1     True 2020-11-20 07:59:19
# 4   43836482-981e-11e9-abac-c412f533dba1     True 2020-11-27 17:17:33
# 5   cf3762bf-f5f9-11e8-ab84-c412f533dba1    False 2020-03-03 17:41:22
# 6   f683a91a-59d5-11e9-ab9c-c412f533dba1     True 2090-01-01 00:00:00
# 7   2502c57d-21ae-11eb-ac1d-c412f533dba1    False 2020-11-08 13:47:18
# 8   00000000-0000-0000-0000-000000000000    False 2090-01-01 00:00:00
# 9   1d7e0076-1792-11eb-ac1d-c412f533dba1    False 2020-10-29 17:41:18
# 10  00000000-0000-0000-0000-000000000000    False 2090-01-01 00:00:00
# 11  73fe0223-d5a3-11e9-abbe-c412f533dba1     True 2090-01-01 00:00:00
# 12  820758c7-6fd8-11e7-80fc-c412f533dba1     True 2020-01-07 08:00:11
# 13  287f1afc-1f48-11eb-ac1d-c412f533dba1     True 2090-01-01 00:00:00
# 14  a9259f72-d5a5-11e9-abbe-c412f533dba1     True 2020-11-14 13:26:08
# 15  00000000-0000-0000-0000-000000000000    False 2090-01-01 00:00:00
# 16  063c88ef-176b-11eb-ac1d-c412f533dba1    False 2090-01-01 00:00:00
# 17  6fbcffdf-19b5-11eb-ac1d-c412f533dba1     True 2090-01-01 00:00:00
# 18  214a6764-d5ae-11e9-abbe-c412f533dba1     True 2090-01-01 00:00:00
# 19  27aed78a-169a-11eb-ac1d-c412f533dba1     True 2090-01-01 00:00:00
#
#     m_real_amount  no_purch_before purchase client_status
# 0         13040.0            False       No            No
# 1             0.0             True       No           Yes
# 2             0.0             True       No           Yes
# 3          8349.0             True       No           Yes
# 4         23641.0             True       No           Yes
# 5           262.0            False      Yes            No
# 6             0.0             True       No           Yes
# 7           197.0            False      Yes            No
# 8             0.0             True       No         Trash
# 9         40739.0             True      Yes            No
# 10            0.0             True       No         Trash
# 11            0.0             True       No           Yes
# 12         3272.0            False       No            No
# 13            0.0             True       No           Yes
# 14        48412.0             True      Yes           Yes
# 15            0.0             True       No         Trash
# 16            0.0             True       No            No
# 17            0.0             True       No           Yes
# 18            0.0             True       No           Yes
# 19            0.0             True       No           Yes

# %%
result['m_real_amount'] = result.apply(lambda x : 0 if x['no_purch_before'] == False else x['m_real_amount'], axis=1)
result
# Out:
#                                    lead_id        created_at_x d_utm_medium  \
# 0     009b1616-145d-11eb-ac1d-c412f533dba1 2020-10-22 15:52:04          cpc
# 1     00aea163-13a5-11eb-ac1d-c412f533dba1 2020-10-21 17:54:59
# 2     00b288c8-1f2a-11eb-ac1d-c412f533dba1 2020-11-05 09:44:43          cpc
# 3     00c4c14a-2456-11eb-ac1d-c412f533dba1 2020-11-11 23:42:17          cpc
# 4     010e6800-1b56-11eb-ac1d-c412f533dba1 2020-10-31 12:49:37          cpc
# ...                                    ...                 ...          ...
# 1970  ff7d0045-12c7-11eb-ac1c-c412f533dba1 2020-10-20 15:32:56          sms
# 1971  ffa2180e-1f72-11eb-ac1d-c412f533dba1 2020-11-05 18:27:15
# 1972  ffaa0815-16c4-11eb-ac1d-c412f533dba1 2020-10-25 17:21:33
# 1973  ffacb5af-194f-11eb-ac1d-c412f533dba1 2020-10-28 23:01:35          cpc
# 1974  ffcdebc8-15c2-11eb-ac1d-c412f533dba1 2020-10-24 10:34:43   utm_medium
#
#      d_utm_source                          l_manager_id  \
# 0              vk  5dd88f32-6501-11ea-abf3-c412f533dba1
# 1         unknown  db06b8bc-bfb2-11e7-8116-c412f533dba1
# 2       instagram  43756fa4-57a0-11e9-ab9a-c412f533dba1
# 3          google  5dd88f32-6501-11ea-abf3-c412f533dba1
# 4       instagram  db06b8bc-bfb2-11e7-8116-c412f533dba1
# ...           ...                                   ...
# 1970        viber  9a87c608-52dc-11ea-abeb-c412f533dba1
# 1971      unknown  b832aac3-fcda-11ea-ac18-c412f533dba1
# 1972      unknown  5dd88f32-6501-11ea-abf3-c412f533dba1
# 1973           vk  ad52c7a8-a752-11e7-8115-c412f533dba1
# 1974      unknown  ad52c7a8-a752-11e7-8115-c412f533dba1
#
#                                l_client_id  First_x         first_purch  \
# 0     ac2c0012-6fd5-11e7-80fc-c412f533dba1     True 2020-04-17 14:48:51
# 1     00aea164-13a5-11eb-ac1d-c412f533dba1     True 2090-01-01 00:00:00
# 2     9c1b0cfa-fd6b-11ea-ac18-c412f533dba1     True 2090-01-01 00:00:00
# 3     bb2c46b7-24b5-11eb-ac1d-c412f533dba1     True 2020-11-20 07:59:19
# 4     43836482-981e-11e9-abac-c412f533dba1     True 2020-11-27 17:17:33
# ...                                    ...      ...                 ...
# 1970  2e4fbe67-12cb-11eb-ac1c-c412f533dba1     True 2090-01-01 00:00:00
# 1971  ffa2180f-1f72-11eb-ac1d-c412f533dba1     True 2020-11-05 15:29:21
# 1972  ffaa0816-16c4-11eb-ac1d-c412f533dba1     True 2090-01-01 00:00:00
# 1973  377ea5e0-d089-11e9-abbd-c412f533dba1     True 2090-01-01 00:00:00
# 1974  f3357d13-15c7-11eb-ac1d-c412f533dba1     True 2090-01-01 00:00:00
#
#       m_real_amount  no_purch_before purchase client_status
# 0               0.0            False       No            No
# 1               0.0             True       No           Yes
# 2               0.0             True       No           Yes
# 3            8349.0             True       No           Yes
# 4           23641.0             True       No           Yes
# ...             ...              ...      ...           ...
# 1970            0.0             True       No           Yes
# 1971            0.0            False       No            No
# 1972            0.0             True       No           Yes
# 1973            0.0             True       No           Yes
# 1974            0.0             True       No           Yes
#
# [1975 rows x 12 columns]

# %%
result.rename(columns={"l_manager_id": "manager_id"},inplace=True)
df_inner_1 = pd.merge(result, managers, on='manager_id', how='left')
#df_inner_1 = pandasql.sqldf("SELECT DISTINCT result.created_at_x, result.l_manager_id, result.d_utm_source, CASE WHEN result.l_manager_id = '00000000-0000-0000-0000-000000000000' THEN 'No manager' ELSE managers.d_manager END AS manager, CASE WHEN result.l_manager_id = '00000000-0000-0000-0000-000000000000' THEN 'No club' ELSE managers.d_club END AS club, result.client_status, result.no_purch_before FROM result LEFT JOIN managers ON result.l_manager_id=managers.manager_id;", globals())

# %%
df_inner_1['d_manager'] = df_inner_1['d_manager'].fillna('unknown')
df_inner_1['d_club'] = df_inner_1['d_club'].fillna('unknown')
df_inner_1['m_real_amount'] = df_inner_1['m_real_amount'].astype(int)
df_inner_1
# Out:
#                                    lead_id        created_at_x d_utm_medium  \
# 0     009b1616-145d-11eb-ac1d-c412f533dba1 2020-10-22 15:52:04          cpc
# 1     00aea163-13a5-11eb-ac1d-c412f533dba1 2020-10-21 17:54:59
# 2     00b288c8-1f2a-11eb-ac1d-c412f533dba1 2020-11-05 09:44:43          cpc
# 3     00c4c14a-2456-11eb-ac1d-c412f533dba1 2020-11-11 23:42:17          cpc
# 4     010e6800-1b56-11eb-ac1d-c412f533dba1 2020-10-31 12:49:37          cpc
# ...                                    ...                 ...          ...
# 1970  ff7d0045-12c7-11eb-ac1c-c412f533dba1 2020-10-20 15:32:56          sms
# 1971  ffa2180e-1f72-11eb-ac1d-c412f533dba1 2020-11-05 18:27:15
# 1972  ffaa0815-16c4-11eb-ac1d-c412f533dba1 2020-10-25 17:21:33
# 1973  ffacb5af-194f-11eb-ac1d-c412f533dba1 2020-10-28 23:01:35          cpc
# 1974  ffcdebc8-15c2-11eb-ac1d-c412f533dba1 2020-10-24 10:34:43   utm_medium
#
#      d_utm_source                            manager_id  \
# 0              vk  5dd88f32-6501-11ea-abf3-c412f533dba1
# 1         unknown  db06b8bc-bfb2-11e7-8116-c412f533dba1
# 2       instagram  43756fa4-57a0-11e9-ab9a-c412f533dba1
# 3          google  5dd88f32-6501-11ea-abf3-c412f533dba1
# 4       instagram  db06b8bc-bfb2-11e7-8116-c412f533dba1
# ...           ...                                   ...
# 1970        viber  9a87c608-52dc-11ea-abeb-c412f533dba1
# 1971      unknown  b832aac3-fcda-11ea-ac18-c412f533dba1
# 1972      unknown  5dd88f32-6501-11ea-abf3-c412f533dba1
# 1973           vk  ad52c7a8-a752-11e7-8115-c412f533dba1
# 1974      unknown  ad52c7a8-a752-11e7-8115-c412f533dba1
#
#                                l_client_id  First_x         first_purch  \
# 0     ac2c0012-6fd5-11e7-80fc-c412f533dba1     True 2020-04-17 14:48:51
# 1     00aea164-13a5-11eb-ac1d-c412f533dba1     True 2090-01-01 00:00:00
# 2     9c1b0cfa-fd6b-11ea-ac18-c412f533dba1     True 2090-01-01 00:00:00
# 3     bb2c46b7-24b5-11eb-ac1d-c412f533dba1     True 2020-11-20 07:59:19
# 4     43836482-981e-11e9-abac-c412f533dba1     True 2020-11-27 17:17:33
# ...                                    ...      ...                 ...
# 1970  2e4fbe67-12cb-11eb-ac1c-c412f533dba1     True 2090-01-01 00:00:00
# 1971  ffa2180f-1f72-11eb-ac1d-c412f533dba1     True 2020-11-05 15:29:21
# 1972  ffaa0816-16c4-11eb-ac1d-c412f533dba1     True 2090-01-01 00:00:00
# 1973  377ea5e0-d089-11e9-abbd-c412f533dba1     True 2090-01-01 00:00:00
# 1974  f3357d13-15c7-11eb-ac1d-c412f533dba1     True 2090-01-01 00:00:00
#
#       m_real_amount  no_purch_before purchase client_status    d_manager  \
# 0                 0            False       No            No  manager #10
# 1                 0             True       No           Yes   manager #4
# 2                 0             True       No           Yes  manager #11
# 3              8349             True       No           Yes  manager #10
# 4             23641             True       No           Yes   manager #4
# ...             ...              ...      ...           ...          ...
# 1970              0             True       No           Yes   manager #9
# 1971              0            False       No            No  manager #13
# 1972              0             True       No           Yes  manager #10
# 1973              0             True       No           Yes   manager #7
# 1974              0             True       No           Yes   manager #7
#
#        d_club
# 0     club #2
# 1     club #2
# 2     club #4
# 3     club #2
# 4     club #2
# ...       ...
# 1970  club #3
# 1971  club #3
# 1972  club #2
# 1973  club #1
# 1974  club #1
#
# [1975 rows x 14 columns]

# %%
df_inner_1 = df_inner_1[['d_utm_source','d_club', 'd_manager', 'client_status', 'purchase', 'm_real_amount']].copy()
df_inner_1
# Out:
#      d_utm_source   d_club    d_manager client_status purchase  m_real_amount
# 0              vk  club #2  manager #10            No       No              0
# 1         unknown  club #2   manager #4           Yes       No              0
# 2       instagram  club #4  manager #11           Yes       No              0
# 3          google  club #2  manager #10           Yes       No           8349
# 4       instagram  club #2   manager #4           Yes       No          23641
# ...           ...      ...          ...           ...      ...            ...
# 1970        viber  club #3   manager #9           Yes       No              0
# 1971      unknown  club #3  manager #13            No       No              0
# 1972      unknown  club #2  manager #10           Yes       No              0
# 1973           vk  club #1   manager #7           Yes       No              0
# 1974      unknown  club #1   manager #7           Yes       No              0
#
# [1975 rows x 6 columns]

# %%
df_inner_1['Trash'] = df_inner_1['client_status'] == 'Trash'
df_inner_1['New_customer'] = df_inner_1['client_status'] == 'Yes'

# %%
df_inner_1['new_purchase'] = result.apply(lambda x : 1 if (x['no_purch_before'] == True) and (x['purchase']=='Yes') else 0, axis=1)
df_inner_1
# Out:
#      d_utm_source   d_club    d_manager client_status purchase  m_real_amount  \
# 0              vk  club #2  manager #10            No       No              0
# 1         unknown  club #2   manager #4           Yes       No              0
# 2       instagram  club #4  manager #11           Yes       No              0
# 3          google  club #2  manager #10           Yes       No           8349
# 4       instagram  club #2   manager #4           Yes       No          23641
# ...           ...      ...          ...           ...      ...            ...
# 1970        viber  club #3   manager #9           Yes       No              0
# 1971      unknown  club #3  manager #13            No       No              0
# 1972      unknown  club #2  manager #10           Yes       No              0
# 1973           vk  club #1   manager #7           Yes       No              0
# 1974      unknown  club #1   manager #7           Yes       No              0
#
#       Trash  New_customer  new_purchase
# 0     False         False             0
# 1     False          True             0
# 2     False          True             0
# 3     False          True             0
# 4     False          True             0
# ...     ...           ...           ...
# 1970  False          True             0
# 1971  False         False             0
# 1972  False          True             0
# 1973  False          True             0
# 1974  False          True             0
#
# [1975 rows x 9 columns]

# %%
df_inner_1.replace([True, False], [1, 0], inplace=True)

# %%
import pygsheets

# %%
gc = pygsheets.authorize(service_file='write_key.json')

# %%
sh = gc.open('Report Anton Selitskiy')

# %%
wks = sh[0]

# %%
wks.set_dataframe(df_inner_1,(1,1),copy_head=True)
